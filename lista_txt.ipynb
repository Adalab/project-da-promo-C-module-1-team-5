# %%
with open('data_txt_reorder.txt','r') as file:
    file_source = file.readlines() # Es una lista que cada línea del fichero txt como un string de todos los datos.

# %%
file_source
# Out:
# ['index_sql;Q3;Q4;Q5;Q6;Q7;Q8;Q9;Q11;Q12;Q13;Q14;Q15;Q16;Q17;Q20;Q21;Q22;Q23;Q24;Q25;Q26;Q32;Q33;Q34;Q35;Q41\n',
#  '1;Indonesia;Master’s degree;Program/Project Manager;20+ years;null, SQL, C, C++, Java;Python;null,   Notepad++  ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Never; Matplotlib ;Under 1 year;  Scikit-learn ;Linear or Logistic Regression, Decision Trees or Random Forests;Manufacturing/Fabrication;1000-9,999 employees;1-2;We are exploring ML methods (and may one day put a model into production);null, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data;60,000-69,999;$0 ($USD);;;;;Advanced statistical software (SPSS, SAS, etc.)\n',
#  '2;Pakistan;Master’s degree;Software Engineer;1-3 years;Python, C++, Java;Python;null,  PyCharm ,  Jupyter Notebook, Other;A laptop;null, Other;Never; Matplotlib ;I do not use machine learning methods;;;Academics/Education;1000-9,999 employees;0;I do not know;null, None of these activities are an important part of my role at work;$0-999;$0 ($USD);MySQL , MongoDB ;MySQL ;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '3;Mexico;Doctoral degree;Research Scientist;20+ years;Python;Python;null,   Spyder  ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc); NVIDIA GPUs ;More than 25 times; Matplotlib ;5-10 years;  Scikit-learn ,   TensorFlow ,  Keras ;null, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks, Recurrent Neural Networks;Academics/Education;1000-9,999 employees;0;I do not know;null, Do research that advances the state of the art of machine learning;30,000-39,999;$0 ($USD);;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '4;India;Doctoral degree;Other;< 1 years;Python, C, MATLAB;Python;null,   Spyder  ,  MATLAB ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Never; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ;10-20 years;  Scikit-learn ,  PyTorch ,  LightGBM ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Evolutionary Approaches;Academics/Education;50-249 employees;5-9;We use ML methods for generating insights (but do not put working models into production);Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas;30,000-39,999;$1000-$9,999;null, None;;null, Microsoft Power BI;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '5;India;I prefer not to answer;Currently not employed;< 1 years;Python;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  PyCharm ,   Spyder  ,  Jupyter Notebook;A laptop;null,  Google Cloud TPUs ;2-5 times; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ,  Fast.ai ;Linear or Logistic Regression, Decision Trees or Random Forests;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '6;India;Some college/university study without earning a bachelor’s degree;Student;1-3 years;null, C++, Java, Javascript;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A laptop;null, None;Never;null,  Geoplotlib ;Under 1 year;null,  Fast.ai ;;;;;;;;;;;;;\n',
#  '7;India;Bachelor’s degree;Data Scientist;5-10 years;Python;Python;null,  Jupyter Notebook;A personal computer / desktop;null,  Google Cloud TPUs ;2-5 times; Matplotlib ,  Plotly / Plotly Express ;2-3 years;  Scikit-learn ,   TensorFlow ,  Keras ;null, Decision Trees or Random Forests, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks, Generative Adversarial Networks;Computers/Technology;10,000 or more employees;3-4;We have well established ML methods (i.e., models in production for more than 2 years);null, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas;15,000-19,999;$1-$99;MySQL ;;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '8;Russia;Bachelor’s degree;Currently not employed;3-5 years;Python, SQL;Python;null, Other;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Never; Matplotlib ;Under 1 year;  Scikit-learn ,  Xgboost ;null, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc);;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '9;Turkey;I prefer not to answer;Other;1-3 years;Python, SQL;SQL;null,   Spyder  ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ;Linear or Logistic Regression;Manufacturing/Fabrication;50-249 employees;1-2;I do not know;Analyze and understand data to influence product or business decisions;$0-999;$0 ($USD);;;;;Business intelligence software (Salesforce, Tableau, Spotfire, etc.)\n',
#  '10;Australia;Doctoral degree;Other;1-3 years;Python, R, SQL;R;null,  RStudio ,  Jupyter Notebook;A personal computer / desktop;null, None;Never; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ;I do not use machine learning methods;;;Other;0-49 employees;0;No (we do not use ML methods);null, None of these activities are an important part of my role at work;70,000-79,999;$1-$99;MySQL ;;null, Microsoft Power BI, Tableau, Alteryx ;Tableau;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '11;India;Master’s degree;Student;< 1 years;Python, R, C++;R;null,  RStudio ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ;Under 1 year;  Scikit-learn ;Linear or Logistic Regression;;;;;;;;;;;;Advanced statistical software (SPSS, SAS, etc.)\n',
#  '12;India;Master’s degree;Student;< 1 years;Python, MATLAB;Python;null,  RStudio ,  MATLAB ,  Jupyter Notebook;A laptop;;;;;;;;;;;;;;;;;;\n',
#  '13;Nigeria;Master’s degree;Program/Project Manager;5-10 years;Python, SQL;Python;null,   Spyder  ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;1-2 years;  Scikit-learn ,  Xgboost ;Linear or Logistic Regression, Decision Trees or Random Forests;Shipping/Transportation;1000-9,999 employees;10-14;We are exploring ML methods (and may one day put a model into production);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data;2,000-2,999;$100-$999;null, Oracle Database ;;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '14;Nigeria;Bachelor’s degree;Other;< 1 years;Python;Python;null,  Visual Studio Code (VSCode) ;A laptop; NVIDIA GPUs ;Once;null,  Plotly / Plotly Express ;Under 1 year;null,   TensorFlow ;Linear or Logistic Regression;Academics/Education;0-49 employees;1-2;No (we do not use ML methods);Analyze and understand data to influence product or business decisions;$0-999;$0 ($USD);;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '15;Greece;Doctoral degree;Research Scientist;10-20 years;Python, C, C++, MATLAB;Python;null,   Spyder  ;A laptop; NVIDIA GPUs ;Never; Matplotlib ;4-5 years;  Scikit-learn , Other;Linear or Logistic Regression, Other;Academics/Education;50-249 employees;5-9;We use ML methods for generating insights (but do not put working models into production);null, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas, Experimentation and iteration to improve existing ML models;10,000-14,999;$0 ($USD);;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '16;Belgium;Bachelor’s degree;Data Analyst;20+ years;Python, SQL;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;1-2 years;  Scikit-learn ;Linear or Logistic Regression;Energy/Mining;1000-9,999 employees;5-9;We are exploring ML methods (and may one day put a model into production);Analyze and understand data to influence product or business decisions;2,000-2,999;$0 ($USD);;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '17;Pakistan;Bachelor’s degree;Data Scientist;1-3 years;Python, SQL;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio Code (VSCode) ,  PyCharm ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Never; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ;Linear or Logistic Regression, Decision Trees or Random Forests, Convolutional Neural Networks;Academics/Education;0-49 employees;3-4;We use ML methods for generating insights (but do not put working models into production);Analyze and understand data to influence product or business decisions, Build and/or run a machine learning service that operationally improves my product or workflows;$0-999;$0 ($USD);;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '18;Japan;Master’s degree;Software Engineer;3-5 years;Python, SQL, C, Java, Javascript;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio Code (VSCode) ,  PyCharm ;A laptop;null, None;Never; Matplotlib ;2-3 years;null,  PyTorch ;Linear or Logistic Regression, Generative Adversarial Networks, Recurrent Neural Networks;;;;;;;;;;;;\n',
#  '19;Egypt;Bachelor’s degree;Other;< 1 years;null, None;R;null,  PyCharm ,   Sublime Text  ;A laptop;null, None;Never;null, None;I do not use machine learning methods;;;Shipping/Transportation;10,000 or more employees;5-9;I do not know;null, None of these activities are an important part of my role at work;5,000-7,499;$0 ($USD);null, None;;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '20;Singapore;Bachelor’s degree;Other;< 1 years;Python;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,   Spyder  ,  MATLAB ;A personal computer / desktop;null, None;Never; Matplotlib ,  Seaborn ;I do not use machine learning methods;;;Manufacturing/Fabrication;250-999 employees;5-9;I do not know;Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas, Do research that advances the state of the art of machine learning;20,000-24,999;$1-$99;null, None;;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '21;Turkey;Bachelor’s degree;Data Scientist;3-5 years;Python, R, SQL, C++;R;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  RStudio ,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A personal computer / desktop; NVIDIA GPUs ;Once; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ,  Xgboost ;Linear or Logistic Regression, Gradient Boosting Machines (xgboost, lightgbm, etc), Dense Neural Networks (MLPs, etc), Convolutional Neural Networks;Computers/Technology;10,000 or more employees;20+;We recently started using ML methods (i.e., models in production for less than 2 years);null, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data;1,000-1,999;$100-$999;null, Oracle Database , MongoDB , IBM Db2 ;IBM Db2 ;null, None;;Advanced statistical software (SPSS, SAS, etc.)\n',
#  '22;Indonesia;Master’s degree;Student;1-3 years;null, R;R;null,  RStudio ;A laptop;null, None;Never;null,  Ggplot / ggplot2 ;I do not use machine learning methods;;;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '23;Brazil;Master’s degree;Machine Learning Engineer;20+ years;Python, SQL, C++;SQL;null,  PyCharm ,  Jupyter Notebook;A deep learning workstation (NVIDIA GTX, LambdaLabs, etc); NVIDIA GPUs ;Never; Matplotlib ,  Seaborn , Other;5-10 years;  Scikit-learn ,   TensorFlow ,  Keras ,  Xgboost ,  LightGBM ,  CatBoost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Dense Neural Networks (MLPs, etc), Recurrent Neural Networks, Transformer Networks (BERT, gpt-3, etc);Computers/Technology;0-49 employees;1-2;We have well established ML methods (i.e., models in production for more than 2 years);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows, Experimentation and iteration to improve existing ML models, Do research that advances the state of the art of machine learning;100,000-124,999;$0 ($USD);;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '24;India;Bachelor’s degree;Student;1-3 years;Python, R, SQL, C, C++, MATLAB;Python;null,  RStudio ,  Visual Studio Code (VSCode) ,  PyCharm ,  MATLAB ,  Jupyter Notebook;A personal computer / desktop;null,  Google Cloud TPUs ;More than 25 times; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ,  Ggplot / ggplot2 ,  Shiny ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ,  Fast.ai ,  Xgboost ,  LightGBM ,  PyTorch Lightning ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Convolutional Neural Networks, Generative Adversarial Networks, Recurrent Neural Networks, Transformer Networks (BERT, gpt-3, etc);;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '25;Poland;Master’s degree;Machine Learning Engineer;3-5 years;Python, C++;Python;null,  Visual Studio Code (VSCode) ,  PyCharm ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Once; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ,  Xgboost ,  CatBoost ;null, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Convolutional Neural Networks;Computers/Technology;0-49 employees;3-4;We recently started using ML methods (i.e., models in production for less than 2 years);Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas, Experimentation and iteration to improve existing ML models;25,000-29,999;$0 ($USD);;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '26;Brazil;Doctoral degree;Research Scientist;< 1 years;Python, R;Python;null,  RStudio ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;Under 1 year;  Scikit-learn ;Linear or Logistic Regression, Decision Trees or Random Forests;Academics/Education;50-249 employees;0;We are exploring ML methods (and may one day put a model into production);null, Do research that advances the state of the art of machine learning;$0-999;$0 ($USD);;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '27;China;Master’s degree;Student;3-5 years;Python, C, C++;Python;null,  PyCharm ,  MATLAB ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Once; Matplotlib ,  Plotly / Plotly Express ;1-2 years;null,   TensorFlow ,  PyTorch ;Linear or Logistic Regression, Bayesian Approaches, Convolutional Neural Networks, Recurrent Neural Networks;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '28;Iran, Islamic Republic of...;Bachelor’s degree;Data Scientist;3-5 years;Python;Python;null,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;More than 25 times; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;Under 1 year;  Scikit-learn ,  Xgboost ,  LightGBM ,  CatBoost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Convolutional Neural Networks;Academics/Education;0-49 employees;0;I do not know;Analyze and understand data to influence product or business decisions, Build and/or run a machine learning service that operationally improves my product or workflows;$0-999;$0 ($USD);;;;;\n',
#  '29;India;Bachelor’s degree;Student;< 1 years;Python, Java;Python;null,  PyCharm ;A laptop;null, None;Never;null, None;I do not use machine learning methods;;;;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '30;India;Bachelor’s degree;Other;1-3 years;Python;Python;null,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;I do not use machine learning methods;;;Computers/Technology;1000-9,999 employees;0;I do not know;null, None of these activities are an important part of my role at work;7,500-9,999;$100-$999;null, None;;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '31;India;Master’s degree;Data Scientist;5-10 years;Python, R, SQL;Python;null,  Visual Studio Code (VSCode) ;A personal computer / desktop; NVIDIA GPUs ;More than 25 times;null,  Altair ;5-10 years;null,  Fast.ai ,  H2O 3 ,  PyTorch Lightning ,  Huggingface ;null, Decision Trees or Random Forests;Insurance/Risk Assessment;250-999 employees;20+;We have well established ML methods (i.e., models in production for more than 2 years);null, Build and/or run a machine learning service that operationally improves my product or workflows;100,000-124,999;$100,000 or more ($USD);null, SQLite ;;null, Other;;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '32;United States of America;Some college/university study without earning a bachelor’s degree;Data Analyst;< 1 years;null, R;R;null,  RStudio ;A personal computer / desktop; NVIDIA GPUs ;Never;null,  Ggplot / ggplot2 ;I do not use machine learning methods;;;Manufacturing/Fabrication;250-999 employees;3-4;;;;;;;;;\n',
#  '33;Egypt;Bachelor’s degree;Data Analyst;3-5 years;Python;R;null,   Notepad++  ,  Jupyter Notebook;A laptop;null, Other;Never;null, None;I do not use machine learning methods;;;Non-profit/Service;0-49 employees;0;No (we do not use ML methods);Analyze and understand data to influence product or business decisions;7,500-9,999;$0 ($USD);null, None;;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '34;India;Bachelor’s degree;Student;1-3 years;Python, C, C++, Java, Javascript, MATLAB;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ,  PyCharm ,   Sublime Text  ,  MATLAB ,  Jupyter Notebook;A laptop;null, None;Never;null, None;Under 1 year;null, None;Linear or Logistic Regression, Decision Trees or Random Forests, Dense Neural Networks (MLPs, etc), Transformer Networks (BERT, gpt-3, etc);;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '35;Brazil;Bachelor’s degree;Currently not employed;< 1 years;Python, R, SQL;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  RStudio ,  PyCharm ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Ggplot / ggplot2 ;Under 1 year;null, None;null, None;;;;;;;;;;;;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '36;Egypt;Master’s degree;Currently not employed;< 1 years;Python, SQL;R;null,  PyCharm ,  Jupyter Notebook;A laptop;null, None;Once; Matplotlib ;Under 1 year;null,  LightGBM ,  CatBoost ;null, Dense Neural Networks (MLPs, etc);;;;;;;;;;;;\n',
#  '37;Brazil;Bachelor’s degree;Student;3-5 years;Python, Java, Javascript;Python;null,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Never; Matplotlib ;I do not use machine learning methods;;;;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '38;Japan;No formal education past high school;Software Engineer;3-5 years;Python, SQL, Java, Other;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ;A personal computer / desktop; NVIDIA GPUs ;Never;null, None;I do not use machine learning methods;;;Computers/Technology;0-49 employees;0;No (we do not use ML methods);null, None of these activities are an important part of my role at work;2,000-2,999;$0 ($USD);MySQL , PostgreSQL , Oracle Database ;PostgreSQL ;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '39;India;Bachelor’s degree;Student;< 1 years;Python, C++;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ,   Spyder  ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Never; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ,  Xgboost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Convolutional Neural Networks;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '40;Brazil;Master’s degree;Data Scientist;5-10 years;Python, SQL;Python;null,  PyCharm ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;2-3 years;  Scikit-learn ,  Xgboost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc);Insurance/Risk Assessment;10,000 or more employees;10-14;We recently started using ML methods (i.e., models in production for less than 2 years);Analyze and understand data to influence product or business decisions, Build and/or run a machine learning service that operationally improves my product or workflows;;;;;;;\n',
#  '41;Italy;Master’s degree;Other;1-3 years;Python, MATLAB;MATLAB;null,  Visual Studio ,  MATLAB ;A laptop;null, None;Never;null, None;Under 1 year;null, None;null, None;Energy/Mining;0-49 employees;1-2;No (we do not use ML methods);null, None of these activities are an important part of my role at work;30,000-39,999;$1-$99;null, None;;null, None;;Other\n',
#  '42;United States of America;Master’s degree;Software Engineer;10-20 years;Python, SQL, Java;Python;null,  PyCharm ;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, Other;Never; Matplotlib ;3-4 years;  Scikit-learn ,   TensorFlow ,  Keras ;Linear or Logistic Regression, Decision Trees or Random Forests, Transformer Networks (BERT, gpt-3, etc);Computers/Technology;0-49 employees;3-4;We recently started using ML methods (i.e., models in production for less than 2 years);null, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data;15,000-19,999;$1000-$9,999;MySQL , Amazon RDS ;MySQL ;Amazon QuickSight, Tableau;Tableau;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '43;Viet Nam;Master’s degree;Machine Learning Engineer;1-3 years;Python;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  RStudio ,  Jupyter Notebook;A laptop;null,  Google Cloud TPUs ;More than 25 times; Matplotlib ,  Ggplot / ggplot2 ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ;null, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks;Academics/Education;50-249 employees;1-2;No (we do not use ML methods);null, Experimentation and iteration to improve existing ML models, Do research that advances the state of the art of machine learning;4,000-4,999;$1000-$9,999;null, None;;null, Domo;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '44;United States of America;Some college/university study without earning a bachelor’s degree;Student;1-3 years;Python, C, C++, Other;C;null,   Vim / Emacs  ;A laptop;null, None;Never;null, None;Under 1 year;null, None;null, None;;;;;;;;;;;;\n',
#  '45;Israel;Master’s degree;Data Scientist;3-5 years;Python, C++, MATLAB;Python;null,  Visual Studio ,  PyCharm ,   Notepad++  ,  MATLAB ,  Jupyter Notebook;A personal computer / desktop;null, None;Never; Matplotlib ,  Seaborn ,  Bokeh ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ;Linear or Logistic Regression, Decision Trees or Random Forests, Dense Neural Networks (MLPs, etc);Accounting/Finance;50-249 employees;5-9;We have well established ML methods (i.e., models in production for more than 2 years);Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows, Experimentation and iteration to improve existing ML models;100,000-124,999;$10,000-$99,999;MySQL ;;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '46;China;Some college/university study without earning a bachelor’s degree;Data Analyst;< 1 years;Python, SQL, C, C++, Java, Javascript, MATLAB;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio ,  Visual Studio Code (VSCode) ,  PyCharm ,  MATLAB ,  Jupyter Notebook;A personal computer / desktop; NVIDIA GPUs ;2-5 times; Matplotlib ,  Plotly / Plotly Express ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ;Linear or Logistic Regression, Decision Trees or Random Forests;Computers/Technology;0-49 employees;0;No (we do not use ML methods);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows;$0-999;$0 ($USD);;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '47;Egypt;Bachelor’s degree;Student;1-3 years;Python, R;R;null,  PyCharm ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ,  Ggplot / ggplot2 ;Under 1 year;  Scikit-learn ;Linear or Logistic Regression;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '48;India;Bachelor’s degree;Machine Learning Engineer;3-5 years;Python, SQL, Java, Javascript, MATLAB, Other;Python;null,  Visual Studio Code (VSCode) ,   Notepad++  ,  Jupyter Notebook;A laptop; NVIDIA GPUs ,  Google Cloud TPUs ;2-5 times; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;2-3 years;  Scikit-learn ,   TensorFlow ,  Keras ,  Xgboost ,  LightGBM ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Convolutional Neural Networks, Recurrent Neural Networks;Hospitality/Entertainment/Sports;10,000 or more employees;3-4;We have well established ML methods (i.e., models in production for more than 2 years);Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows, Experimentation and iteration to improve existing ML models;1,000-1,999;$1-$99;MySQL , PostgreSQL , Google Cloud Firestore , Google Cloud BigTable ;Google Cloud Firestore ;null, None;;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '49;United States of America;Master’s degree;Data Scientist;5-10 years;Python, SQL;Python;null,   Spyder  ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Never; Matplotlib ,  Seaborn ;4-5 years;  Scikit-learn ,  Xgboost ,  Prophet ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc);Other;10,000 or more employees;10-14;We recently started using ML methods (i.e., models in production for less than 2 years);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas;100,000-124,999;$1000-$9,999;null, Google Cloud BigQuery ;;null, Google Data Studio, Looker, Tableau;Tableau;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '50;Peru;Some college/university study without earning a bachelor’s degree;Currently not employed;< 1 years;Python, R, SQL;Julia;null,  RStudio ,  Visual Studio Code (VSCode) ,  PyCharm ,   Spyder  ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null,  Google Cloud TPUs ;Once;null,  Seaborn ,  Ggplot / ggplot2 ,  Shiny ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ,  Xgboost ,  LightGBM ,  CatBoost ,  Caret ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Dense Neural Networks (MLPs, etc), Transformer Networks (BERT, gpt-3, etc);;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '51;United States of America;Bachelor’s degree;Research Scientist;< 1 years;null, None;SQL;null, None;A laptop;null, None;Never;null, None;I do not use machine learning methods;;;Manufacturing/Fabrication;1000-9,999 employees;1-2;I do not know;Analyze and understand data to influence product or business decisions;70,000-79,999;$0 ($USD);null, None;;null, None;;Advanced statistical software (SPSS, SAS, etc.)\n',
#  '52;South Africa;Master’s degree;Data Analyst;1-3 years;null, R, SQL;R;null,  RStudio ,  Jupyter Notebook;A laptop;null, None;Never;null,  Plotly / Plotly Express ,  Ggplot / ggplot2 ,  Shiny ;1-2 years;null,  Caret ,  Tidymodels ;Linear or Logistic Regression, Decision Trees or Random Forests, Bayesian Approaches, Evolutionary Approaches;Manufacturing/Fabrication;250-999 employees;1-2;No (we do not use ML methods);Analyze and understand data to influence product or business decisions;25,000-29,999;$100-$999;null, None;;null, Microsoft Power BI;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '53;Other;Master’s degree;Business Analyst;1-3 years;Python, SQL, Other;Python;null,  PyCharm , Other;A laptop;null, None;Never; Matplotlib ;1-2 years;  Scikit-learn ,  Xgboost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc);Accounting/Finance;50-249 employees;0;No (we do not use ML methods);null, None of these activities are an important part of my role at work;60,000-69,999;$1-$99;null, Microsoft SQL Server ;;null, Tableau;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '54;Spain;Master’s degree;Currently not employed;1-3 years;null, SQL, Javascript, Bash;Python;null,  Visual Studio Code (VSCode) ;A laptop;null, None;Never;null, None;I do not use machine learning methods;;;;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '55;Bangladesh;Bachelor’s degree;Software Engineer;5-10 years;null, C++, Other;Python;null,  Visual Studio ;A laptop;null, None;Never; Matplotlib ;2-3 years;  Scikit-learn ,   TensorFlow ,  Keras ;null, Recurrent Neural Networks;Computers/Technology;250-999 employees;10-14;I do not know;null, None of these activities are an important part of my role at work;7,500-9,999;$0 ($USD);;;;;Other\n',
#  '56;Indonesia;Master’s degree;Student;1-3 years;Python;Python;null,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Once; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;;;;;;;;;;;;;;;\n',
#  '57;Russia;I prefer not to answer;Data Scientist;1-3 years;Python, R;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Jupyter Notebook;A personal computer / desktop;null,  Google Cloud TPUs ;Never; Matplotlib ,  Plotly / Plotly Express ,  Ggplot / ggplot2 ,  D3 js ;I do not use machine learning methods;;;Academics/Education;1000-9,999 employees;3-4;I do not know;Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas, Experimentation and iteration to improve existing ML models;$0-999;$0 ($USD);;;;;\n',
#  '58;India;Bachelor’s degree;Machine Learning Engineer;1-3 years;Python, SQL, C;C;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio ,  Visual Studio Code (VSCode) ,  PyCharm ,  Jupyter Notebook;A personal computer / desktop;null, None;Once; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ,  Bokeh ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ,  Xgboost ,  Huggingface ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Dense Neural Networks (MLPs, etc), Convolutional Neural Networks;Computers/Technology;50-249 employees;20+;We recently started using ML methods (i.e., models in production for less than 2 years);null, Do research that advances the state of the art of machine learning;$0-999;$1-$99;null, PostgreSQL , SQLite , Oracle Database ;Oracle Database ;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '59;India;Bachelor’s degree;Program/Project Manager;1-3 years;Python, SQL;Python;null,  PyCharm ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ;1-2 years;  Scikit-learn ;Linear or Logistic Regression;Government/Public Service;10,000 or more employees;0;I do not know;null, Other;2,000-2,999;$1-$99;MySQL ;;null, Microsoft Power BI;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '60;Japan;Some college/university study without earning a bachelor’s degree;Student;< 1 years;null, C++;Python;null,  Visual Studio Code (VSCode) ,   Spyder  ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ;Under 1 year;  Scikit-learn ,  Xgboost ;null, Gradient Boosting Machines (xgboost, lightgbm, etc);;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '61;Russia;Bachelor’s degree;Machine Learning Engineer;3-5 years;Python, C++;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ,  PyCharm ,   Notepad++  ,   Sublime Text  ;A personal computer / desktop;null, None;Never; Matplotlib ,  Seaborn ;Under 1 year;null, None;Linear or Logistic Regression, Decision Trees or Random Forests;Computers/Technology;0-49 employees;0;I do not know;null, Other;$0-999;$0 ($USD);;;;;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '62;Japan;Master’s degree;Data Scientist;1-3 years;Python, SQL, Bash;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  RStudio ,  Visual Studio Code (VSCode) ,   Vim / Emacs  ;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null,  Google Cloud TPUs ;More than 25 times; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ,  Ggplot / ggplot2 ;4-5 years;  Scikit-learn ,   TensorFlow ,  PyTorch ,  Xgboost ,  LightGBM ,  CatBoost ,  Tidymodels ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks, Generative Adversarial Networks, Recurrent Neural Networks, Transformer Networks (BERT, gpt-3, etc);Online Service/Internet-based Services;250-999 employees;5-9;We recently started using ML methods (i.e., models in production for less than 2 years);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows, Experimentation and iteration to improve existing ML models;40,000-49,999;$100-$999;null, Google Cloud BigQuery ;;null, Google Data Studio, Tableau;Tableau;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '63;India;Bachelor’s degree;Student;< 1 years;Python, C, Javascript;Python;null,  Visual Studio Code (VSCode) ,   Sublime Text  ;A laptop;null, None;Never;null, None;Under 1 year;null, None;null, None;;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '64;India;Bachelor’s degree;Student;1-3 years;Python, C, C++;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A laptop;null, None;2-5 times; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ,  Fast.ai ;Linear or Logistic Regression, Bayesian Approaches, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '65;Russia;Doctoral degree;Data Engineer;1-3 years;Python, Javascript, Bash, MATLAB;Python;null,  Visual Studio Code (VSCode) ,  MATLAB ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;2-5 times; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ;Linear or Logistic Regression, Convolutional Neural Networks, Recurrent Neural Networks;Accounting/Finance;0-49 employees;10-14;We have well established ML methods (i.e., models in production for more than 2 years);Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows, Do research that advances the state of the art of machine learning;$0-999;$1000-$9,999;null, PostgreSQL ;;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '66;China;I prefer not to answer;Data Analyst;< 1 years;Python;Python;null,  PyCharm ,   Spyder  ;A laptop;null, None;Never;null, None;Under 1 year;null, Other;null, Other;Computers/Technology;0-49 employees;0;I do not know;Analyze and understand data to influence product or business decisions;$0-999;$0 ($USD);;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '67;Other;Master’s degree;Business Analyst;1-3 years;Python;Python;null,   Spyder  ,  Jupyter Notebook;A personal computer / desktop; NVIDIA GPUs ;Never; Matplotlib ,  Seaborn ;1-2 years;null,   TensorFlow ,  Keras ;Linear or Logistic Regression, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks, Recurrent Neural Networks;Online Service/Internet-based Services;1000-9,999 employees;1-2;No (we do not use ML methods);Analyze and understand data to influence product or business decisions;7,500-9,999;$100-$999;null, Microsoft SQL Server ;;null, Microsoft Power BI;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '68;India;Bachelor’s degree;Other;< 1 years;Python, R;Python;null,  RStudio ,  PyCharm ,   Spyder  ,   Notepad++  ,  Jupyter Notebook;A laptop; NVIDIA GPUs ,  Google Cloud TPUs ;2-5 times; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ,  Geoplotlib ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ,  Xgboost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Dense Neural Networks (MLPs, etc), Recurrent Neural Networks;Online Business/Internet-based Sales;0-49 employees;1-2;We are exploring ML methods (and may one day put a model into production);Analyze and understand data to influence product or business decisions, Do research that advances the state of the art of machine learning;2,000-2,999;$1000-$9,999;null, None;;null, Microsoft Power BI, Tableau, SAP Analytics Cloud ;Microsoft Power BI;Business intelligence software (Salesforce, Tableau, Spotfire, etc.)\n',
#  '69;United Kingdom of Great Britain and Northern Ireland;Master’s degree;Other;20+ years;Python, Javascript;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio Code (VSCode) ,  Jupyter Notebook, Other;A laptop; NVIDIA GPUs ;Never; Matplotlib ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ;Linear or Logistic Regression, Decision Trees or Random Forests, Convolutional Neural Networks, Generative Adversarial Networks, Recurrent Neural Networks;Online Service/Internet-based Services;250-999 employees;5-9;We are exploring ML methods (and may one day put a model into production);Analyze and understand data to influence product or business decisions, Build prototypes to explore applying machine learning to new areas;50,000-59,999;$100,000 or more ($USD);null, None;;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '70;India;Bachelor’s degree;Currently not employed;< 1 years;Python, R, SQL;Python;null,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ,  Ggplot / ggplot2 ;Under 1 year;  Scikit-learn ,  Xgboost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches;;;;;;;;;;;;\n',
#  '71;Mexico;Some college/university study without earning a bachelor’s degree;Other;3-5 years;null, SQL, Javascript;Python;null,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ;Linear or Logistic Regression, Decision Trees or Random Forests;Online Business/Internet-based Sales;0-49 employees;0;We are exploring ML methods (and may one day put a model into production);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows;5,000-7,499;$1-$99;null, Google Cloud Firestore ;;null, None;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '72;Iran, Islamic Republic of...;Master’s degree;Software Engineer;5-10 years;null, SQL, Java;Python;null,  Visual Studio ,   Notepad++  , Other;A laptop;null, Other;Never;null, Other;I do not use machine learning methods;;;Computers/Technology;1000-9,999 employees;20+;We are exploring ML methods (and may one day put a model into production);null, None of these activities are an important part of my role at work;3,000-3,999;$0 ($USD);null, IBM Db2 , Microsoft SQL Server ;Microsoft SQL Server ;null, Other;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '73;Turkey;Master’s degree;Program/Project Manager;20+ years;Python, Java;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  PyCharm ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Never;null,  Seaborn ;1-2 years;  Scikit-learn ,  Keras ,  Prophet ;Linear or Logistic Regression, Decision Trees or Random Forests;Academics/Education;250-999 employees;5-9;We are exploring ML methods (and may one day put a model into production);Analyze and understand data to influence product or business decisions;3,000-3,999;$100-$999;null, Amazon DynamoDB ;;null, Looker;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '74;Brazil;Master’s degree;Student;5-10 years;Python, C++;Python;null,  Visual Studio Code (VSCode) ,   Sublime Text  ,  Jupyter Notebook;A personal computer / desktop; NVIDIA GPUs ;Never; Matplotlib ,  Altair ;2-3 years;null,   TensorFlow ,  Keras ;Linear or Logistic Regression, Dense Neural Networks (MLPs, etc), Convolutional Neural Networks;;;;;;;;;;;;\n',
#  '75;France;Doctoral degree;Research Scientist;3-5 years;Python, C++, MATLAB;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,   Spyder  ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc); NVIDIA GPUs ;2-5 times; Matplotlib ,  Seaborn ;2-3 years;  Scikit-learn ,  Keras ;Linear or Logistic Regression, Decision Trees or Random Forests, Bayesian Approaches, Convolutional Neural Networks;Manufacturing/Fabrication;0-49 employees;1-2;I do not know;Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows, Experimentation and iteration to improve existing ML models, Do research that advances the state of the art of machine learning;3,000-3,999;$0 ($USD);;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '76;United States of America;Master’s degree;Data Engineer;20+ years;Python, Bash;Python;null,  Visual Studio Code (VSCode) ,   Vim / Emacs  ;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc); NVIDIA GPUs ,  Google Cloud TPUs ;6-25 times;null,  Seaborn ;I do not use machine learning methods;;;Computers/Technology;10,000 or more employees;1-2;We have well established ML methods (i.e., models in production for more than 2 years);null, None of these activities are an important part of my role at work;300,000-499,999;$100,000 or more ($USD);MySQL , PostgreSQL , MongoDB , Amazon RDS ;MySQL ;null, Salesforce;;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '77;China;Master’s degree;Business Analyst;< 1 years;Python;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  PyCharm ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Once; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ,  Bokeh ;Under 1 year;  Scikit-learn ;Linear or Logistic Regression, Decision Trees or Random Forests;Accounting/Finance;1000-9,999 employees;20+;We recently started using ML methods (i.e., models in production for less than 2 years);Analyze and understand data to influence product or business decisions;20,000-24,999;$10,000-$99,999;null, PostgreSQL ;;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '78;Switzerland;Doctoral degree;Student;5-10 years;Python, MATLAB;Python;null,  Visual Studio Code (VSCode) ,  PyCharm ,  MATLAB ;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Never; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;2-3 years;  Scikit-learn ,   TensorFlow ,  Keras ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Dense Neural Networks (MLPs, etc);;;;;;;;;;;;Other\n',
#  '79;India;Bachelor’s degree;Currently not employed;1-3 years;Python, SQL, C, C++, Javascript;R;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio ,  Visual Studio Code (VSCode) ,   Sublime Text  ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;I do not use machine learning methods;;;;;;;;;;;;;;\n',
#  '80;United States of America;Professional doctorate;Research Scientist;10-20 years;Python, R, SQL, Javascript, Julia, Swift;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  RStudio ,  Visual Studio Code (VSCode) ,  PyCharm ,  Jupyter Notebook;A personal computer / desktop; NVIDIA GPUs ;2-5 times; Matplotlib ,  Plotly / Plotly Express ,  Ggplot / ggplot2 ,  D3 js ;5-10 years;  Scikit-learn ,  PyTorch ,  Fast.ai ,  Xgboost ,  PyTorch Lightning ,  Huggingface ;null, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Recurrent Neural Networks, Transformer Networks (BERT, gpt-3, etc);Medical/Pharmaceutical;10,000 or more employees;20+;We use ML methods for generating insights (but do not put working models into production);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas;200,000-249,999;$10,000-$99,999;null, PostgreSQL , Amazon RDS , Amazon DynamoDB , Google Cloud Firestore ;PostgreSQL ;null, Other;;Local development environments (RStudio, JupyterLab, etc.)\n',
# ...
#  '969;India;Bachelor’s degree;Business Analyst;1-3 years;Python, SQL, C, MATLAB;SQL;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio ;A laptop;null, None;Never; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ;Linear or Logistic Regression, Decision Trees or Random Forests, Bayesian Approaches, Convolutional Neural Networks, Recurrent Neural Networks;Online Service/Internet-based Services;10,000 or more employees;10-14;We use ML methods for generating insights (but do not put working models into production);Analyze and understand data to influence product or business decisions;15,000-19,999;$100-$999;null, Oracle Database ;;null, Tableau;;Business intelligence software (Salesforce, Tableau, Spotfire, etc.)\n',
#  '970;Japan;Master’s degree;Software Engineer;3-5 years;null, SQL, Java;Python;null,  Visual Studio Code (VSCode) , Other;A personal computer / desktop; NVIDIA GPUs ;Never;null, None;Under 1 year;null, None;null, None;Computers/Technology;0-49 employees;0;No (we do not use ML methods);null, None of these activities are an important part of my role at work;2,000-2,999;$0 ($USD);;;;;\n',
#  '971;South Korea;Bachelor’s degree;Research Scientist;3-5 years;Python, R, SQL, C, MATLAB;Python;null,  RStudio ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;2-5 times; Matplotlib ,  Seaborn ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ;null, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Dense Neural Networks (MLPs, etc), Convolutional Neural Networks;Manufacturing/Fabrication;0-49 employees;1-2;We are exploring ML methods (and may one day put a model into production);null, Build prototypes to explore applying machine learning to new areas;40,000-49,999;$10,000-$99,999;null, None;;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '972;India;Bachelor’s degree;Data Analyst;I have never written code;;;;;;;;;;;Accounting/Finance;0-49 employees;0;I do not know;null, None of these activities are an important part of my role at work;$0-999;$0 ($USD);;;;;\n',
#  '973;India;I prefer not to answer;Data Scientist;5-10 years;Python;Python;null,  PyCharm ;A laptop;null, None;Once; Matplotlib ,  Seaborn ;1-2 years;null,  PyTorch ,  Huggingface ;Linear or Logistic Regression, Decision Trees or Random Forests, Recurrent Neural Networks, Transformer Networks (BERT, gpt-3, etc);Academics/Education;0-49 employees;1-2;We are exploring ML methods (and may one day put a model into production);null, None of these activities are an important part of my role at work;$0-999;$1-$99;null, None;;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '974;Ireland;Doctoral degree;Other;< 1 years;Python, C, Javascript;Python;null,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A personal computer / desktop;null, None;Never; Matplotlib ;Under 1 year;null,  Fast.ai ;null, Decision Trees or Random Forests;Other;0-49 employees;1-2;We are exploring ML methods (and may one day put a model into production);Analyze and understand data to influence product or business decisions;20,000-24,999;$100-$999;null, None;;null, Tableau;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '975;Pakistan;Bachelor’s degree;Currently not employed;< 1 years;Python, SQL, C, C++, Javascript;Python;null,   Notepad++  ;A laptop;null, None;Never; Matplotlib ;I do not use machine learning methods;;;;;;;;;;;;;;\n',
#  '976;India;Some college/university study without earning a bachelor’s degree;Data Engineer;1-3 years;Python, SQL, C, C++, Java, Other;Python;null,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, Other;Never; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,  PyTorch ;Linear or Logistic Regression, Gradient Boosting Machines (xgboost, lightgbm, etc), Convolutional Neural Networks;Computers/Technology;10,000 or more employees;15-19;We use ML methods for generating insights (but do not put working models into production);null, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data;$0-999;$0 ($USD);;;;;Other\n',
#  '977;France;Doctoral degree;Machine Learning Engineer;5-10 years;Python, C++, Bash;Python;null,  Visual Studio Code (VSCode) ,  PyCharm ;A personal computer / desktop; NVIDIA GPUs ;Never; Matplotlib ;5-10 years;  Scikit-learn ,  PyTorch ,  PyTorch Lightning ;null, Convolutional Neural Networks, Other;Computers/Technology;50-249 employees;5-9;We recently started using ML methods (i.e., models in production for less than 2 years);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Experimentation and iteration to improve existing ML models;70,000-79,999;$0 ($USD);;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '978;India;Master’s degree;Data Analyst;1-3 years;Python, SQL, Other;Python;null,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Never; Matplotlib ;Under 1 year;  Scikit-learn ;Linear or Logistic Regression, Decision Trees or Random Forests;Insurance/Risk Assessment;10,000 or more employees;3-4;No (we do not use ML methods);Analyze and understand data to influence product or business decisions;10,000-14,999;$0 ($USD);;;;;Advanced statistical software (SPSS, SAS, etc.)\n',
#  '979;India;Master’s degree;Data Analyst;< 1 years;Python, SQL, C;Python;null,  PyCharm ;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc);null, None;Once; Matplotlib ;Under 1 year;  Scikit-learn ;null, Recurrent Neural Networks, Transformer Networks (BERT, gpt-3, etc);Computers/Technology;250-999 employees;10-14;We recently started using ML methods (i.e., models in production for less than 2 years);null, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build and/or run a machine learning service that operationally improves my product or workflows;200,000-249,999;$100-$999;null, SQLite , Google Cloud SQL ;Google Cloud SQL ;Amazon QuickSight;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '980;Egypt;Master’s degree;Data Analyst;< 1 years;Python;SQL;null,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;I do not use machine learning methods;;;Medical/Pharmaceutical;1000-9,999 employees;0;No (we do not use ML methods);Analyze and understand data to influence product or business decisions;$0-999;$0 ($USD);;;;;\n',
#  '981;Indonesia;Bachelor’s degree;Student;5-10 years;Python, SQL, C++, Javascript;Python;null,  Visual Studio Code (VSCode) ,   Sublime Text  ;A laptop;null, None;Never; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Keras ;null, Decision Trees or Random Forests, Convolutional Neural Networks;;;;;;;;;;;;Other\n',
#  '982;South Korea;Doctoral degree;Machine Learning Engineer;3-5 years;Python, R, SQL, MATLAB;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ,  PyCharm ;A personal computer / desktop; NVIDIA GPUs ;6-25 times; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;2-3 years;null,   TensorFlow ,  Keras ,  PyTorch ,  Prophet ,  PyTorch Lightning ;null, Gradient Boosting Machines (xgboost, lightgbm, etc), Dense Neural Networks (MLPs, etc), Convolutional Neural Networks, Recurrent Neural Networks;Manufacturing/Fabrication;10,000 or more employees;20+;We have well established ML methods (i.e., models in production for more than 2 years);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build prototypes to explore applying machine learning to new areas, Build and/or run a machine learning service that operationally improves my product or workflows, Do research that advances the state of the art of machine learning;100,000-124,999;$1000-$9,999;MySQL , SQLite , Oracle Database , MongoDB , Microsoft SQL Server ;Oracle Database ;null, Tableau, TIBCO Spotfire;TIBCO Spotfire;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '983;India;Bachelor’s degree;DBA/Database Engineer;3-5 years;Python, SQL, Java;Python;null,  Visual Studio ,  PyCharm ,   Spyder  ,   Notepad++  ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;1-2 years;  Scikit-learn ,   TensorFlow ,  Keras ;Linear or Logistic Regression, Decision Trees or Random Forests, Dense Neural Networks (MLPs, etc);Computers/Technology;1000-9,999 employees;5-9;No (we do not use ML methods);Analyze and understand data to influence product or business decisions;$0-999;$0 ($USD);;;;;Cloud-based data software & APIs (AWS, GCP, Azure, etc.)\n',
#  '984;India;I prefer not to answer;Student;< 1 years;null, R;R;null,  RStudio ;A laptop;null, Other;Never;null, Other;I do not use machine learning methods;;;;;;;;;;;;;;Business intelligence software (Salesforce, Tableau, Spotfire, etc.)\n',
#  '985;India;Master’s degree;Business Analyst;1-3 years;null, SQL;Python;null,  RStudio ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;1-2 years;  Scikit-learn ;Linear or Logistic Regression, Decision Trees or Random Forests;Marketing/CRM;10,000 or more employees;20+;We have well established ML methods (i.e., models in production for more than 2 years);Analyze and understand data to influence product or business decisions;15,000-19,999;$0 ($USD);;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '986;India;Bachelor’s degree;Student;1-3 years;Python, C, Java, MATLAB;C;null,  Visual Studio Code (VSCode) ,  MATLAB ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;Never;null, Other;I do not use machine learning methods;;;;;;;;;;;;;;\n',
#  '987;India;Master’s degree;Currently not employed;1-3 years;Python, C, C++, Java, Javascript;Python;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  MATLAB ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;I do not use machine learning methods;;;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '988;Turkey;Master’s degree;Currently not employed;1-3 years;Python, C++, Java;Python;null,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ;Linear or Logistic Regression, Decision Trees or Random Forests;;;;;;;;;;;;\n',
#  '989;Spain;Doctoral degree;Research Scientist;20+ years;Python, R;R;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  RStudio ;A laptop; NVIDIA GPUs ;2-5 times;null,  Plotly / Plotly Express ,  Ggplot / ggplot2 ,  Shiny ;20 or more years;  Scikit-learn ,   TensorFlow ,  Xgboost ,  Caret ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Transformer Networks (BERT, gpt-3, etc);Academics/Education;1000-9,999 employees;10-14;We use ML methods for generating insights (but do not put working models into production);Analyze and understand data to influence product or business decisions, Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data, Build and/or run a machine learning service that operationally improves my product or workflows;50,000-59,999;$100-$999;MySQL , MongoDB ;MySQL ;null, None;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '990;Portugal;Doctoral degree;Currently not employed;10-20 years;Python;Python;null,  PyCharm ,   Spyder  ,  Jupyter Notebook;A cloud computing platform (AWS, Azure, GCP, hosted notebooks, etc); NVIDIA GPUs ;2-5 times; Matplotlib ,  Seaborn ;Under 1 year;  Scikit-learn ,   TensorFlow ,  Xgboost ,  LightGBM ,  CatBoost ;Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Convolutional Neural Networks, Generative Adversarial Networks;;;;;;;;;;;;Advanced statistical software (SPSS, SAS, etc.)\n',
#  '991;Egypt;Some college/university study without earning a bachelor’s degree;Student;1-3 years;Python;Python;null,   Spyder  ;A laptop;null, None;Never; Matplotlib ,  Seaborn ;1-2 years;  Scikit-learn ,  Fast.ai ;;;;;;;;;;;;;\n',
#  '992;Ireland;Bachelor’s degree;Software Engineer;5-10 years;Python, SQL, Javascript, Other;Python;null,  Visual Studio ,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A personal computer / desktop; NVIDIA GPUs ,  Google Cloud TPUs ;6-25 times; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;Under 1 year;  Scikit-learn ,  Xgboost ,  LightGBM ;null, Gradient Boosting Machines (xgboost, lightgbm, etc), Bayesian Approaches, Convolutional Neural Networks;Government/Public Service;1000-9,999 employees;0;We use ML methods for generating insights (but do not put working models into production);null, None of these activities are an important part of my role at work;30,000-39,999;$1-$99;;;;;\n',
#  '993;Indonesia;Some college/university study without earning a bachelor’s degree;Student;< 1 years;Python, R;Python;null,   Sublime Text  ,  Jupyter Notebook;A laptop;null, None;Never;null, None;Under 1 year;  Scikit-learn ;null, Bayesian Approaches, Dense Neural Networks (MLPs, etc);;;;;;;;;;;;Basic statistical software (Microsoft Excel, Google Sheets, etc.)\n',
#  '994;China;Master’s degree;Data Analyst;3-5 years;Python, C, C++, Java;Java;Jupyter (JupyterLab, Jupyter Notebooks, etc) ,  Visual Studio Code (VSCode) ,  PyCharm ,   Notepad++  ,  MATLAB ,  Jupyter Notebook;A personal computer / desktop; NVIDIA GPUs ,  AWS Inferentia Chips ;6-25 times;null,  Altair ,  Bokeh ,  Leaflet / Folium ;3-4 years;null,   TensorFlow ,  Keras ,  Huggingface ;null, Bayesian Approaches, Dense Neural Networks (MLPs, etc);Energy/Mining;0-49 employees;5-9;We recently started using ML methods (i.e., models in production for less than 2 years);null, Build prototypes to explore applying machine learning to new areas, Experimentation and iteration to improve existing ML models;80,000-89,999;$1000-$9,999;null, SQLite , IBM Db2 , Microsoft SQL Server ;Microsoft SQL Server ;null, Google Data Studio;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '995;India;Master’s degree;Student;< 1 years;Python, SQL, C, Java;Python;null,  Visual Studio Code (VSCode) ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;I do not use machine learning methods;;;;;;;;;;;;;;\n',
#  '996;India;Master’s degree;Business Analyst;< 1 years;Python;Python;null,  PyCharm ;A laptop;null, None;Never; Matplotlib ,  Seaborn ,  Plotly / Plotly Express ;I do not use machine learning methods;;;;;;;;;;;;;;\n',
#  '997;Taiwan;Master’s degree;Software Engineer;3-5 years;Python, SQL, Javascript;Python;null,  Visual Studio ,   Notepad++  ;None;null, None;Never;null,  D3 js ;I do not use machine learning methods;;;Computers/Technology;1000-9,999 employees;5-9;No (we do not use ML methods);null, None of these activities are an important part of my role at work;$0-999;$1-$99;null, Oracle Database ;;null, None;;\n',
#  '998;Other;Bachelor’s degree;Student;3-5 years;Python, R, C++, MATLAB;Python;null,  RStudio ,  MATLAB ,  Jupyter Notebook;A laptop;null, None;Never; Matplotlib ,  Seaborn ;2-3 years;  Scikit-learn ,   TensorFlow ,  Keras ,  PyTorch ;Linear or Logistic Regression, Decision Trees or Random Forests, Bayesian Approaches, Convolutional Neural Networks, Generative Adversarial Networks, Recurrent Neural Networks;;;;;;;;;;;;Local development environments (RStudio, JupyterLab, etc.)\n',
#  '999;Japan;Master’s degree;Research Scientist;3-5 years;Python, C++;Python;null,  Visual Studio Code (VSCode) ,  PyCharm ,  Jupyter Notebook;A laptop; NVIDIA GPUs ;;;;;;;;;;;;;;;;;\n',
#  ...]
